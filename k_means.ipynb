# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
from sklearn.datasets import load_sample_image
from matplotlib import pyplot as plt
import numpy as np

# %%
img = load_sample_image("china.jpg")

# %%
ax = plt.axes(xticks=[], yticks=[])
ax.imshow(img)

# %%
img.shape # 3D
# Out:
# (427, 640, 3)

# %%
data = img/255.0  # to make it in scale (0,1)
data = data.reshape(427*640, 3) #to make it 2D

# %%
data.shape
# Out:
# (273280, 3)

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
kmeans = MiniBatchKMeans(16) # k = 16
# reduse the color of image to 16 color

# %%
kmeans.fit(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# MiniBatchKMeans(n_clusters=16)

# %%
new_colors = kmeans.cluster_centers_[kmeans.predict(data)]

# %%
img_new = new_colors.reshape(img.shape)

fig, ax = plt.subplots(1, 2, figsize = (16, 6), subplot_kw = dict(xticks = [], yticks = []))
fig.subplots_adjust(wspace = 0.05)
ax[0].imshow(img)
ax[0].set_title('Original Image', size = 16)
ax[1].imshow(img_new)
ax[1].set_title('16-color Image', size = 16)
plt.show()
